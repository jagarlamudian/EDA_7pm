# %%
# import yhe packages
# read teh data
# divide the cat 


import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
path=r"C:\Users\jagar\Documents\Visadataset.csv"
visa_df=pd.read_csv(path)
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **prevailing_wage**

# %% [markdown]
# - len
# - max
# - min
# - mean
# - median
# - 25percentile
# - 50percentile
# - 75percentile

# %%
wage_data=visa_df['prevailing_wage']
len(wage_data)
# Out:
# 25480

# %%
min(wage_data)
# Out:
# 2.1367

# %%
max(wage_data)
# Out:
# 319210.27

# %%
np.min(wage_data)
# Out:
# 2.1367

# %%
np.max(wage_data)
# Out:
# 319210.27

# %%
wage_data=visa_df['prevailing_wage']
min(wage_data),wage_data.min(),np.min(wage_data)
# Out:
# (2.1367, 2.1367, 2.1367)

# %%
max(wage_data),wage_data.max(),np.max(wage_data)
# Out:
# (319210.27, 319210.27, 319210.27)

# %%
wage_data.mean(),np.mean(wage_data)
# Out:
# (np.float64(74455.81459209183), np.float64(74455.81459209183))

# %%
wage_data.median(),np.median(wage_data)
# Out:
# (70308.20999999999, np.float64(70308.20999999999))

# %% [markdown]
# **quantile-percentile**

# %%
import numpy as np
p_25=np.percentile(wage_data,25)
p_25
# Out:
# np.float64(34015.479999999996)

# %%
import numpy as np
p_50=np.percentile(wage_data,50)
p_50
# Out:
# np.float64(70308.20999999999)

# %%
import numpy as np
p_75=np.percentile(wage_data,75)
p_75
# Out:
# np.float64(107735.51250000001)

# %% [markdown]
# **quantile**

# %%
import numpy as np
p_25=np.quantile(wage_data,0.25)
p_25
# Out:
# np.float64(34015.479999999996)

# %%
import numpy as np
p_50=np.quantile(wage_data,0.25)
p_50
# Out:
# np.float64(34015.479999999996)

# %%
import numpy as np
p_75=np.quantile(wage_data,0.25)
p_75
# Out:
# np.float64(34015.479999999996)

# %%
wage_data=visa_df['prevailing_wage']
wage_count=len(wage_data)
wage_min=round(wage_data.min(),2)
wage_mean=round(wage_data.mean(),2)
wage_med=round(wage_data.median(),2)
wage_25p=round(np.percentile(wage_data,25))
wage_50p=round(np.percentile(wage_data,50))
wage_75p=round(np.percentile(wage_data,75))
wage_max=round(wage_data.max(),2)
l=[wage_count,wage_min,wage_mean,wage_med,wage_25p,wage_50p,
   wage_75p,wage_max]
Id=['Count','Min','Max','Median','25p','50p',
    '75p','Max']
pd.DataFrame(l,columns=['prevailing_wage'],index=Id)
# Out:
#         prevailing_wage
# Count          25480.00
# Min                2.14
# Max            74455.81
# Median         70308.21
# 25p            34015.00
# 50p            70308.00
# 75p           107736.00
# Max           319210.27

# %%
L=[]
for i in num:
    data=visa_df[i]
    Count=len(data)
    Min=round(data.min(),2)
    Mean=round(data.mean(),2)
    Med=round(data.median(),2)
    p25=round(np.percentile(data,25))
    p50=round(np.percentile(data,50))
    p75=round(np.percentile(data,75))
    Max=round(wage_data.max(),2)
    l=[Count,Min,Mean,Med,p25,p50,
       p75,Max]
    Id=['Count','Min','Max','Median','25p','50p',
        '75p','Max']
    L.append(l)
pd.DataFrame(L,index=num,columns=Id).T
# Out:
#         no_of_employees  yr_of_estab  prevailing_wage
# Count          25480.00     25480.00         25480.00
# Min              -26.00      1800.00             2.14
# Max             5667.04      1979.41         74455.81
# Median          2109.00      1997.00         70308.21
# 25p             1022.00      1976.00         34015.00
# 50p             2109.00      1997.00         70308.00
# 75p             3504.00      2005.00        107736.00
# Max           319210.27    319210.27        319210.27

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# **percentile concept**
#
# - 25p:25percentage of data below 25p value
#
# - wage_25p:34015.48
#
#     - there 25*(25480)/100=6370 appllications have salary less than 34015
#
# - wage_50p:70308.12
#
#     - there 50*(25480)/100=15740 application have salary less than 70308.12
#
# - wage_50p:107735.51
#
#     - there 50*(25480)/100=19110 application have salary less than 107735.51

# %%
con=visa_df['prevailing_wage']<wage_25p
len(visa_df[con]),len(visa_df)*25/100
len(visa_df[con])==len(visa_df)*25/100
# Out:
# True

# %%
len(visa_df)*25/100
# Out:
# 6370.0

# %%
con=visa_df['prevailing_wage']<wage_50p
len(visa_df[con]),len(visa_df)*50/100
len(visa_df[con])==len(visa_df)*50/100
# Out:
# True

# %%
con=visa_df['prevailing_wage']<wage_75p
len(visa_df[con]),len(visa_df)*75/100
len(visa_df[con])==len(visa_df)*75/100
# Out:
# True

# %% [markdown]
# **Empirical rule**

# %%
wage_data=visa_df['prevailing_wage']
U=wage_data.mean()
sigma=wage_data.std()
LB=U-1*sigma
UB=U+1*sigma
con1=visa_df['prevailing_wage']>LB
con2=visa_df['prevailing_wage']<UB
con=con1 & con2
len(visa_df[con])==68*25480/100
# Out:
# False

# %%
# Conclusion:Emperical rule failed wage data does not following Normal distribution

# %% [markdown]
# **Histogram**

# %%
plt.hist(wage_data,bins=40)
# Out:
# (array([2992.,  871., 1005., 1170., 1242., 1434., 1385., 1443., 1444.,
#         1445., 1457., 1335., 1268., 1217., 1088.,  978.,  807.,  645.,
#          509.,  373.,  264.,  144.,  105.,  111.,  107.,   99.,   88.,
#           79.,   65.,   64.,   58.,   53.,   33.,   33.,   29.,   19.,
#            7.,    3.,    6.,    5.]),
#  array([2.13670000e+00, 7.98234003e+03, 1.59625434e+04, 2.39427467e+04,
#         3.19229500e+04, 3.99031534e+04, 4.78833567e+04, 5.58635600e+04,
#         6.38437634e+04, 7.18239667e+04, 7.98041700e+04, 8.77843734e+04,
#         9.57645767e+04, 1.03744780e+05, 1.11724983e+05, 1.19705187e+05,
#         1.27685390e+05, 1.35665593e+05, 1.43645797e+05, 1.51626000e+05,
#         1.59606203e+05, 1.67586407e+05, 1.75566610e+05, 1.83546813e+05,
#         1.91527017e+05, 1.99507220e+05, 2.07487423e+05, 2.15467627e+05,
#         2.23447830e+05, 2.31428033e+05, 2.39408237e+05, 2.47388440e+05,
#         2.55368643e+05, 2.63348847e+05, 2.71329050e+05, 2.79309253e+05,
#         2.87289457e+05, 2.95269660e+05, 3.03249863e+05, 3.11230067e+05,
#         3.19210270e+05]),
#  <BarContainer object of 40 artists>)

# %%
plt.hist(wage_data,bins=10)        # bin is nothing but intervals
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)

# %%
inter_count,inter_vals,n=plt.hist(wage_data,bins=10)

# %%
inter_count
# Out:
# array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#          21.])

# %%
inter_vals
# Out:
# array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#        1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#        2.55368643e+05, 2.87289457e+05, 3.19210270e+05])

# %%
2.13670000e+00,3.19229500e+04
# Out:
# (2.1367, 31922.95)

# %%
3.19229500e+04
# Out:
# 31922.95

# %%
wage_data=visa_df['prevailing_wage']
lb=2.13670000e+00

con1=visa_df['prevailing_wage']>LB
con2=visa_df['prevailing_wage']<UB
con=con1 & con2
len(visa_df[con])==3.19229500e+04/1000
# Out:
# False

# %%
len(wage_data)>2.13670000e+00<3.19229500e+04
# Out:
# True

# %%
len(wage_data)<3.19229500e+04
# Out:
# True

# %% [markdown]
# **Outlier analysis**

# %% [markdown]
# - we understood emperical rule failed
# - Then we plotted histogram its slightly deviated
# - So it indicates the data has outliers

# %% [markdown]
# **box plot**

# %%
import pandas as pd
path=r"C:\Users\jagar\Documents\Visadataset.csv"
visa_df=pd.read_csv(path)

# %%
import matplotlib.pyplot as plt
wage_data=visa_df['prevailing_wage']
plt.boxplot(wage_data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b9ef9cf110>,
#   <matplotlib.lines.Line2D at 0x1b9ef9cf250>],
#  'caps': [<matplotlib.lines.Line2D at 0x1b9ef9cf390>,
#   <matplotlib.lines.Line2D at 0x1b9ef9cf4d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1b9ef9cefd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b9ef9cf610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b9ef9cf750>],
#  'means': []}

# %%
import matplotlib.pyplot as plt
wage_data=visa_df['prevailing_wage']
plt.boxplot(wage_data,vert=False)
plt.show()

# %%
import pandas as pd
path=r"C:\Users\jagar\Documents\Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
wage_data=visa_df['prevailing_wage']
plt.pie(wage_data)
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.subplot(1,2,1).hist(wage_data)
plt.subplot(1,2,2).boxplot(wage_data,vert=False)
plt.show()

# %% [markdown]
# **outliers data**

# %%
import numpy as np
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q1-1.5*IQR
con1=wage_data>UB
con2=wage_data<LB
con=con1|con2
outliers_df=visa_df[con]
len(outliers_df)
# Out:
# 427

# %%
import numpy as np
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q1-1.5*IQR
con1=wage_data<UB
con2=wage_data>LB
con=con1&con2
nonoutliers_df=visa_df[con]
len(nonoutliers_df)
# Out:
# 25053

# %% [markdown]
# **Fill the outliers**
#
# - drop the outliers
# - fill with median
# - winsorization:fill will LB and UB

# %%
outliers=outliers_df['prevailing_wage'].values.tolist()
wage_data=visa_df['prevailing_wage']
wage_med=wage_data.median()
l=[]
for value in visa_df['prevailing_wage']:
    if value in outliers_df:
        l.append(wage_data)
    else:
        l.append(value)
l
# Out:
# [592.2029,
#  83425.65,
#  122996.86,
#  83434.03,
#  149907.39,
#  78252.14,
#  53635.39,
#  418.2298,
#  74362.19,
#  67514.76,
#  83588.56,
#  70813.09,
#  28663.05,
#  107196.03,
#  220081.73,
#  74108.02,
#  3706.79,
#  16132.61,
#  150441.13,
#  79948.12,
#  71128.98,
#  137694.98,
#  45642.39,
#  90108.38,
#  71286.04,
#  99489.65,
#  86332.95,
#  103029.33,
#  40925.86,
#  189190.48,
#  79594.12,
#  135866.13,
#  72077.57,
#  81921.18,
#  225569.73,
#  92421.92,
#  2490.12,
#  110817.26,
#  50960.01,
#  125336.9,
#  39633.32,
#  156326.33,
#  43630.58,
#  54614.42,
#  28989.87,
#  22924.91,
#  61567.75,
#  156251.17,
#  86022.02,
#  49565.37,
#  66191.41,
#  95623.2,
#  115014.05,
#  35018.04,
#  230.8072,
#  113799.64,
#  85854.09,
#  14174.04,
#  47176.84,
#  4949.28,
#  67410.59,
#  58791.58,
#  103.2216,
#  62591.57,
#  102919.59,
#  123468.56,
#  82324.64,
#  5319.49,
#  153019.94,
#  38059.89,
#  230.327,
#  61521.92,
#  121316.5,
#  122540.55,
#  47170.76,
#  330.3743,
#  2927.34,
#  107781.48,
#  590.0203,
#  194176.83,
#  102073.81,
#  113882.38,
#  70778.82,
#  84125.48,
#  174014.59,
#  34213.17,
#  79813.05,
#  113327.34,
#  78893.64,
#  140290.16,
#  111926.01,
#  125880.21,
#  527.8901,
#  49357.95,
#  69335.2,
#  99737.18,
#  91449.62,
#  34494.86,
#  395.995,
#  159645.51,
#  28243.79,
#  43421.88,
#  80253.78,
#  115235.95,
#  95200.86,
#  41613.52,
#  64137.41,
#  66295.43,
#  97520.02,
#  65164.57,
#  73957.17,
#  71415.43,
#  87336.53,
#  98966.72,
#  83503.6,
#  57590.66,
#  32400.2,
#  65993.21,
#  32161.6,
#  16421.37,
#  160676.39,
#  53114.02,
#  19176.21,
#  204832.52,
#  40256.03,
#  38841.44,
#  133052.84,
#  75234.64,
#  37032.83,
#  61617.73,
#  247393.01,
#  341.0229,
#  30570.95,
#  19477.1,
#  164893.0,
#  131584.5,
#  63896.35,
#  77883.22,
#  108519.14,
#  47002.53,
#  88720.29,
#  60821.75,
#  66324.69,
#  100398.58,
#  51282.75,
#  13322.72,
#  357.8194,
#  4787.43,
#  149023.92,
#  123739.41,
#  529.1105,
#  68933.4,
#  412.3476,
#  128931.59,
#  37751.51,
#  81781.43,
#  6256.18,
#  44539.97,
#  104281.71,
#  125323.7,
#  81816.46,
#  4027.85,
#  56117.39,
#  113212.16,
#  47095.57,
#  123437.12,
#  65894.51,
#  174333.19,
#  192.157,
#  71825.63,
#  50362.77,
#  9078.62,
#  10341.89,
#  61740.3,
#  61031.95,
#  31986.79,
#  93384.38,
#  109921.68,
#  122535.0,
#  105898.54,
#  134350.49,
#  126498.81,
#  113366.37,
#  100401.52,
#  128173.92,
#  313.835,
#  88809.74,
#  138032.0,
#  630.66,
#  29469.17,
#  123688.79,
#  111179.86,
#  102909.59,
#  128850.75,
#  113637.4,
#  179675.58,
#  15814.94,
#  21511.58,
#  94252.62,
#  89207.07,
#  74441.11,
#  99469.71,
#  31890.66,
#  167376.13,
#  130404.72,
#  84130.53,
#  89079.05,
#  82464.74,
#  158.3807,
#  62640.94,
#  116642.18,
#  53767.37,
#  115777.03,
#  101399.51,
#  146374.48,
#  21282.82,
#  269321.68,
#  52114.54,
#  2390.74,
#  73623.94,
#  141796.39,
#  219529.62,
#  195404.0,
#  158569.72,
#  135792.52,
#  100379.63,
#  138925.72,
#  118458.61,
#  688.1266,
#  112028.45,
#  808.582,
#  112881.33,
#  7794.05,
#  7113.47,
#  100786.62,
#  87390.54,
#  93644.17,
#  118555.6,
#  114512.69,
#  59125.18,
#  26325.98,
#  56606.54,
#  51886.04,
#  62112.22,
#  63108.03,
#  39452.99,
#  80580.97,
#  37291.82,
#  95974.61,
#  21846.43,
#  61147.07,
#  120148.75,
#  206941.23,
#  91689.54,
#  76214.85,
#  65458.88,
#  62730.52,
#  21651.43,
#  102598.35,
#  56422.81,
#  141372.27,
#  138642.17,
#  143628.65,
#  35760.36,
#  3456.8,
#  42469.25,
#  45614.3,
#  108458.31,
#  62950.34,
#  162990.52,
#  84521.88,
#  141129.7,
#  85218.35,
#  118.84,
#  154428.88,
#  65108.59,
#  21001.69,
#  57370.96,
#  99714.22,
#  139424.83,
#  20951.91,
#  66329.37,
#  88447.6,
#  123018.45,
#  165.2722,
#  12800.02,
#  103390.44,
#  25419.59,
#  82385.6,
#  42761.33,
#  98119.94,
#  2007.26,
#  84899.65,
#  26813.7,
#  367.31,
#  116370.47,
#  32086.09,
#  205084.59,
#  45860.87,
#  69741.05,
#  101371.21,
#  93644.47,
#  248.01,
#  155042.99,
#  596.2488,
#  53304.04,
#  34738.65,
#  69375.0,
#  30066.16,
#  67204.54,
#  56065.53,
#  18035.36,
#  100850.52,
#  133586.58,
#  24968.7,
#  115801.09,
#  268.1379,
#  667.4133,
#  117.85,
#  112655.02,
#  135250.42,
#  132240.65,
#  65376.07,
#  111254.68,
#  94830.46,
#  232227.33,
#  125246.83,
#  36028.54,
#  238691.32,
#  34168.31,
#  91290.38,
#  83239.29,
#  62586.7,
#  29260.86,
#  84716.62,
#  54424.62,
#  16551.46,
#  42321.96,
#  15.7716,
#  104457.29,
#  69113.96,
#  66711.21,
#  25512.46,
#  20687.36,
#  97325.13,
#  120371.72,
#  51610.24,
#  96146.09,
#  220448.17,
#  23272.21,
#  106937.84,
#  37069.3,
#  98331.32,
#  3683.43,
#  196668.77,
#  69228.82,
#  33645.87,
#  109700.58,
#  30668.32,
#  99753.8,
#  68751.19,
#  111724.66,
#  227.1764,
#  86133.77,
#  43754.7,
#  67492.78,
#  48943.43,
#  49256.63,
#  112853.73,
#  144312.48,
#  93506.62,
#  198752.64,
#  18476.27,
#  97353.15,
#  152912.99,
#  50067.16,
#  85495.84,
#  19525.49,
#  32506.14,
#  197452.18,
#  45850.33,
#  53519.51,
#  142325.74,
#  74603.2,
#  124317.33,
#  323.7,
#  73225.28,
#  101949.05,
#  107875.51,
#  68683.19,
#  137985.25,
#  35868.69,
#  21976.68,
#  79840.12,
#  99201.01,
#  64084.23,
#  123519.71,
#  11287.42,
#  45261.26,
#  112831.03,
#  113927.99,
#  103200.45,
#  33049.76,
#  113911.27,
#  197676.15,
#  293.3152,
#  206.4596,
#  157199.78,
#  81806.42,
#  100969.89,
#  59533.78,
#  27345.68,
#  26459.67,
#  65681.0,
#  12367.86,
#  297.1948,
#  79380.0,
#  108989.75,
#  56188.13,
#  188992.63,
#  42657.8,
#  94230.51,
#  20141.7,
#  18679.63,
#  27280.53,
#  299.6081,
#  102915.07,
#  230750.48,
#  100.98,
#  113440.66,
#  547.5103,
#  31023.47,
#  95886.8,
#  411.2051,
#  129450.64,
#  69068.26,
#  27132.34,
#  72239.48,
#  88925.59,
#  67086.02,
#  83824.94,
#  23649.64,
#  118922.84,
#  104.23,
#  114790.58,
#  170188.95,
#  1857.39,
#  122859.37,
#  86901.23,
#  78096.9,
#  78402.72,
#  22784.52,
#  62656.12,
#  124439.76,
#  72354.96,
#  43147.38,
#  248.6583,
#  235339.91,
#  41696.75,
#  92071.0,
#  46080.75,
#  172504.71,
#  40926.81,
#  95560.45,
#  115034.46,
#  28280.53,
#  36979.16,
#  10057.24,
#  71977.54,
#  27656.02,
#  50293.83,
#  143415.79,
#  37830.16,
#  90094.22,
#  23389.53,
#  88698.51,
#  43697.94,
#  81724.72,
#  89443.72,
#  28237.13,
#  165219.14,
#  24496.71,
#  67959.42,
#  27471.41,
#  132453.43,
#  137179.34,
#  161738.67,
#  78673.0,
#  75960.46,
#  33630.82,
#  64422.65,
#  52988.17,
#  521.0385,
#  232680.65,
#  102169.61,
#  92218.76,
#  125925.71,
#  24197.92,
#  97931.99,
#  61744.57,
#  92549.52,
#  23128.95,
#  10793.45,
#  138190.15,
#  43881.65,
#  98263.2,
#  25114.1,
#  23945.38,
#  19311.82,
#  144869.09,
#  63512.57,
#  76452.7,
#  795.4405,
#  66972.41,
#  256261.78,
#  85004.99,
#  98124.95,
#  13241.64,
#  572.8227,
#  19838.51,
#  95018.17,
#  162988.12,
#  131023.37,
#  55076.16,
#  82450.68,
#  133468.58,
#  786.5458,
#  59136.13,
#  105987.07,
#  252.43,
#  73896.5,
#  26374.66,
#  108888.49,
#  128167.33,
#  37688.62,
#  66092.25,
#  34249.67,
#  99671.66,
#  52654.73,
#  104068.77,
#  82793.8,
#  130636.68,
#  90951.06,
#  30531.03,
#  49122.07,
#  126935.9,
#  79576.59,
#  206970.67,
#  53077.88,
#  43231.47,
#  7777.55,
#  262189.0,
#  90881.96,
#  119767.22,
#  53669.98,
#  133170.7,
#  314.6393,
#  21853.74,
#  117998.47,
#  11404.58,
#  122141.55,
#  153372.73,
#  103847.9,
#  82553.13,
#  27790.82,
#  97466.91,
#  57972.25,
#  130563.12,
#  35504.93,
#  109604.4,
#  7439.91,
#  80604.66,
#  68564.85,
#  25942.03,
#  70445.67,
#  60158.59,
#  101026.39,
#  149452.3,
#  110382.9,
#  44040.11,
#  62328.16,
#  37049.34,
#  100524.28,
#  60561.95,
#  75815.39,
#  71328.02,
#  832.11,
#  125926.18,
#  21428.58,
#  748.0707,
#  32228.82,
#  152569.46,
#  12210.01,
#  862.3799,
#  81285.88,
#  29099.81,
#  111681.66,
#  164341.96,
#  149649.91,
#  62487.14,
#  35194.51,
#  27978.08,
#  99013.02,
#  14034.51,
#  94398.97,
#  39917.2,
#  70105.8,
#  671.4491,
#  137769.42,
#  76138.64,
#  92324.91,
#  117587.26,
#  49684.23,
#  47844.12,
#  64000.8,
#  47998.71,
#  98429.38,
#  35911.81,
#  200084.9,
#  132029.1,
#  138622.73,
#  105274.65,
#  250510.67,
#  209993.78,
#  77912.67,
#  86235.96,
#  144090.19,
#  147054.85,
#  73503.72,
#  123316.75,
#  81640.69,
#  53999.52,
#  28023.68,
#  30393.57,
#  3.3188,
#  105225.88,
#  87165.0,
#  58800.76,
#  90643.93,
#  84698.17,
#  153307.62,
#  94134.47,
#  81523.82,
#  165723.2,
#  74880.65,
#  51840.34,
#  110427.57,
#  113374.51,
#  134356.0,
#  21924.21,
#  48191.18,
#  125014.69,
#  146020.74,
#  35021.59,
#  111289.39,
#  24055.39,
#  15506.4,
#  45029.5,
#  10837.15,
#  98135.46,
#  52672.96,
#  118601.72,
#  72230.65,
#  102237.74,
#  30409.94,
#  74237.68,
#  25467.02,
#  849.455,
#  64938.71,
#  218554.78,
#  3080.38,
#  212159.14,
#  963.0685,
#  59665.28,
#  256205.38,
#  116867.59,
#  98467.88,
#  20185.76,
#  140154.91,
#  65393.27,
#  142176.75,
#  107882.31,
#  35578.61,
#  104895.32,
#  31857.88,
#  3732.43,
#  92051.71,
#  101086.77,
#  110050.54,
#  92835.68,
#  574.2465,
#  113043.16,
#  148964.53,
#  73401.21,
#  62273.39,
#  106725.35,
#  143188.4,
#  53557.18,
#  86368.98,
#  68182.63,
#  41180.84,
#  51177.11,
#  26097.45,
#  90711.57,
#  27510.78,
#  45530.11,
#  60065.95,
#  80373.13,
#  92422.74,
#  37488.06,
#  31932.69,
#  128946.06,
#  24439.18,
#  138.69,
#  44233.52,
#  101607.49,
#  42704.0,
#  126746.79,
#  153573.56,
#  140381.51,
#  113603.07,
#  14742.8,
#  54639.49,
#  298.1357,
#  45318.93,
#  62003.23,
#  84801.63,
#  66781.76,
#  17561.48,
#  25989.85,
#  60321.97,
#  91822.75,
#  225.6413,
#  22871.53,
#  382.2433,
#  112102.98,
#  95310.74,
#  61829.31,
#  851.4471,
#  26055.3,
#  163906.88,
#  45833.71,
#  28534.67,
#  75796.85,
#  724.0276,
#  43425.93,
#  698.9778,
#  21765.1,
#  157465.74,
#  630.2337,
#  23969.45,
#  111720.08,
#  102986.34,
#  88664.77,
#  101292.33,
#  18251.1,
#  108690.79,
#  88468.41,
#  170788.78,
#  69984.79,
#  68640.89,
#  129255.91,
#  81707.96,
#  60937.35,
#  135441.47,
#  65500.19,
#  108235.72,
#  31190.56,
#  36600.66,
#  141020.04,
#  155605.02,
#  62446.69,
#  9939.67,
#  9693.06,
#  18332.25,
#  77487.08,
#  50417.78,
#  76900.05,
#  40475.41,
#  46457.53,
#  491.9991,
#  38962.34,
#  35244.7,
#  72479.76,
#  13324.91,
#  438.855,
#  33645.75,
#  39848.78,
#  47773.5,
#  868.2749,
#  14125.36,
#  143921.58,
#  17773.53,
#  87966.47,
#  20314.14,
#  22667.46,
#  108527.79,
#  30077.25,
#  26164.47,
#  28611.11,
#  127242.79,
#  924.83,
#  39353.22,
#  54981.44,
#  119943.88,
#  61680.23,
#  16196.99,
#  162410.95,
#  80375.25,
#  71113.2,
#  116374.69,
#  298.8956,
#  185.2334,
#  34770.1,
#  98261.85,
#  82110.68,
#  87058.78,
#  135763.05,
#  96786.88,
#  221944.22,
#  171890.05,
#  50282.8,
#  27532.52,
#  53970.45,
#  4371.14,
#  45855.88,
#  22815.27,
#  101072.99,
#  82062.29,
#  120260.96,
#  101824.5,
#  34229.45,
#  129701.94,
#  66433.79,
#  27828.08,
#  69435.54,
#  10084.11,
#  64888.12,
#  47639.56,
#  61.1329,
#  87397.19,
#  105974.33,
#  79908.73,
#  113260.07,
#  103232.1,
#  75257.3,
#  105748.83,
#  122.55,
#  702.8717,
#  109611.55,
#  746.5986,
#  72618.35,
#  216.15,
#  97504.07,
#  142827.07,
#  75098.79,
#  104593.37,
#  18502.5,
#  104044.4,
#  18706.86,
#  96192.58,
#  25488.09,
#  40804.63,
#  58434.15,
#  20211.1,
#  65759.78,
#  143194.85,
#  467.5247,
#  70544.12,
#  49248.08,
#  103164.26,
#  107772.42,
#  65842.4,
#  12759.63,
#  38933.7,
#  122324.22,
#  82.0029,
#  174.594,
#  89991.95,
#  111021.08,
#  206997.93,
#  44332.36,
#  152856.79,
#  143260.47,
#  215240.7,
#  86070.87,
#  103341.32,
#  109033.72,
#  85647.06,
#  100.1,
#  45108.92,
#  51408.57,
#  40030.56,
#  40223.97,
#  56651.09,
#  109111.37,
#  160323.84,
#  91167.64,
#  95415.3,
#  43427.27,
#  95920.87,
#  95745.58,
#  71594.62,
#  23954.31,
#  116577.94,
#  60750.79,
#  62213.49,
#  75757.9,
#  72752.64,
#  91772.54,
#  95333.45,
#  172316.39,
#  71078.6,
#  109177.73,
#  110328.1,
#  137905.28,
#  10355.64,
#  64445.98,
#  83274.12,
#  62729.69,
#  37505.26,
#  71707.36,
#  90939.96,
#  14671.65,
#  68952.04,
#  24642.85,
#  149133.36,
#  28399.22,
#  62207.61,
#  597.9,
#  98871.58,
#  240.7297,
#  4855.35,
#  58820.08,
#  94129.28,
#  123273.68,
#  93179.7,
#  56474.08,
#  26803.34,
#  41178.56,
#  72863.2,
#  113052.48,
#  229950.7,
#  19383.25,
#  158144.16,
#  132092.7,
#  36364.29,
#  105152.57,
#  40552.46,
#  43614.49,
#  78916.96,
#  138315.14,
#  174812.84,
#  71761.36,
#  74635.08,
#  75224.53,
#  74877.39,
#  62891.29,
#  115239.79,
#  99037.57,
#  97469.69,
#  69825.5,
#  276.7576,
#  3435.99,
#  32421.05,
#  122187.35,
#  62376.12,
#  41360.5,
#  103813.15,
#  139924.14,
#  32341.12,
#  26217.34,
#  65227.99,
#  81132.15,
#  79079.87,
#  132150.73,
#  98867.47,
#  311.1659,
#  41439.87,
#  106460.43,
#  30497.97,
#  89256.68,
#  95016.97,
#  16780.57,
#  78553.09,
#  125702.65,
#  29951.72,
#  144548.82,
#  50956.99,
#  70892.12,
#  72626.0,
#  39114.03,
#  142300.54,
#  314.2371,
#  56495.99,
#  47.4872,
#  109711.81,
#  208952.02,
#  88780.76,
#  48947.85,
#  ...]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,4))
plt.subplot(2,2,1).hist(visa_df['prevailing_wage'])
plt.subplot(2,2,2).boxplot(visa_df['prevailing_wage'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b990a0ead0>,
#   <matplotlib.lines.Line2D at 0x1b990a0ec10>],
#  'caps': [<matplotlib.lines.Line2D at 0x1b990a0ed50>,
#   <matplotlib.lines.Line2D at 0x1b990a0ee90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1b990a0e990>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b990a0efd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b990a0f110>],
#  'means': []}

# %%
wage_data=visa_df['prevailing_wage']
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q1-1.5*IQR
visa_df['prevailing_wage2']=wage_data.clip(lower=LB,upper=UB)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status  prevailing_wage2
# 0          Denied         592.20290
# 1       Certified       83425.65000
# 2          Denied      122996.86000
# 3          Denied       83434.03000
# 4       Certified      149907.39000
# ...           ...               ...
# 25475   Certified       77092.57000
# 25476   Certified      218315.56125
# 25477   Certified      146298.85000
# 25478   Certified       86154.77000
# 25479   Certified       70876.91000
#
# [25480 rows x 13 columns]
